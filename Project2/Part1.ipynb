# %%
install.packages(c("igraph","latex2exp","gsubfn","ramify"))
# Out:
# package 'igraph' successfully unpacked and MD5 sums checked
# package 'latex2exp' successfully unpacked and MD5 sums checked
# package 'gsubfn' successfully unpacked and MD5 sums checked
# package 'ramify' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\shash\AppData\Local\Temp\RtmpYvXVzn\downloaded_packages

# %%
library(igraph)
library(latex2exp)
library(gsubfn)
# Out:
# Warning message:
# "package 'igraph' was built under R version 3.6.3"
# Attaching package: 'igraph'
#
# The following objects are masked from 'package:stats':
#
#     decompose, spectrum
#
# The following object is masked from 'package:base':
#
#     union
#
# Warning message:
# "package 'latex2exp' was built under R version 3.6.3"Warning message:
# "package 'gsubfn' was built under R version 3.6.3"Loading required package: proto
# Warning message:
# "package 'proto' was built under R version 3.6.3"

# %%
library(ramify)
# Out:
# Warning message:
# "package 'ramify' was built under R version 3.6.3"
# Attaching package: 'ramify'
#
# The following object is masked from 'package:graphics':
#
#     clip

# %%
printf <- function(...) cat(sprintf(...))
logspace <- function( d1, d2, n) exp(log(10)*seq(d1, d2, length.out=n))

# %% [markdown]
# # Part 1 - Facebook network

# %% [markdown]
# In this project, we will be using the dataset given below:
# http://snap.stanford.edu/data/egonets-Facebook.html

# %% [markdown]
# ## 1. Structural properties of the Facebook network

# %%
edge_lines = readLines("facebook_combined.txt")

# %%
length(edge_lines)
# Out:
# [1] 88234

# %%
edge_list = matrix(0, length(edge_lines), 2)

# %%
for(i in 1:length(edge_lines)){
    edge_line = edge_lines[i]
    edge = sapply(strsplit(edge_line, " "), as.numeric)
    edge_list[i, 1] = edge[1]+1
    edge_list[i, 2] = edge[2]+1
}

# %%
flat_edge_list = as.vector(edge_list)

# %%
g = graph_from_edgelist(edge_list, directed=F)

# %% [markdown]
# ### Q1

# %%
print(vcount(g))
# Out:
# [1] 4039

# %%
print(ecount(g))
# Out:
# [1] 88234

# %%
print(is_connected(g))
# Out:
# [1] TRUE

# %% [markdown]
# ### Q2

# %%
diameter(g)
# Out:
# [1] 8

# %% [markdown]
# ### Q3

# %%
plot(degree_distribution(g), main="Degree distribution of original graph", xlab=TeX('Degree'), ylab=TeX('Frequency'))
png(sprintf("plots/p2q1_3.png"))
plot(degree_distribution(g), xlab=TeX('Degree'), ylab=TeX('Frequency'))
dev.off()
# Out:
# png
#   2
# Plot with title "Degree distribution of original graph"

# %%
deg = degree(g)

# %%
mean(deg)
# Out:
# [1] 43.69101

# %% [markdown]
# ### Q4

# %%
remove_zero_freqs = function(distr){
    return (list((1:length(distr))[distr>0], distr[distr>0]))
}

# %%
fit_line = function(x, y, log=FALSE){
    if(log){
        slope <- getElement(lm(log(y) ~ log(x))$coefficients[2], "log(x)")
        intercept <- getElement(lm(log(y) ~ log(x))$coefficients[1], "(Intercept)")
    }
    else{
        slope <- getElement(lm(y ~ x)$coefficients[2], "x")
        intercept <- getElement(lm(y ~ x)$coefficients[1], "(Intercept)")
    }
    return (list(slope, intercept))
}

# %%
draw_degree_distribution = function(g){
    list[degrees, degree_freq] <- remove_zero_freqs(degree_distribution(g))
    list[slope, int] <- fit_line(degrees, degree_freq, log=TRUE)
    
    png(sprintf("plots/p2q1_4.png"))
    plot(log(degrees), log(degree_freq), type="b", xlab="log(Degree)", ylab="log(Frequency)", main=sprintf("slope=%.4f", slope))
    abline(lm(log(degree_freq) ~ log(degrees)), col="red")
    dev.off()
    
    plot(log(degrees), log(degree_freq), type="b", xlab="log(Degree)", ylab="log(Frequency)", main=sprintf("slope=%.4f", slope))
    abline(lm(log(degree_freq) ~ log(degrees)), col="red")
    return (slope)
}

# %%
draw_degree_distribution(g)
# Out:
# [1] -1.247526
# Plot with title "slope=-1.2475"

# %% [markdown]
# ## 2. Personalized network

# %% [markdown]
# ### Q5

# %%
personalized_1 = make_ego_graph(g, order = 1, nodes = 1)[[1]]
vertex_size <- rep(4, vcount(personalized_1))
vertex_size[1] <- 8
vertex_color <- rep("lightblue", vcount(personalized_1))
vertex_color[1] <- "gold"

# %%
plot(personalized_1,vertex.size=vertex_size, vertex.label=NA,vertex.color=vertex_color)
# Out:
# Plot with title ""

# %%
print(length(personalized_1))
# Out:
# [1] 10

# %%
vcount(personalized_1)
# Out:
# [1] 348

# %%
ecount(personalized_1)
# Out:
# [1] 2866

# %% [markdown]
# ### Q6

# %%
diameter(personalized_1)
# Out:
# [1] 2

# %% [markdown]
# Upper bound 4, Lower bound 1 (or 0)

# %% [markdown]
# ### Q7

# %% [markdown]
# ## 3. Core node's personalized network

# %%
degrees = degree(g)

# %%
print(length(degrees))
# Out:
# [1] 4039

# %%
core_degrees = degrees[degrees > 200]

# %% [markdown]
# ### Q8

# %%
length(core_degrees)
# Out:
# [1] 40

# %%
mean(core_degrees)
# Out:
# [1] 279.375

# %%
degree(g, v=1087)
# Out:
# [1] 205

# %%
core_nodes = c(1, 108, 349, 484, 1087)

# %%
for(v in V(g)){
    V(g)[v]$id <- v
}

# %%
personalized_networks = make_ego_graph(g, order = 1, nodes = core_nodes)

# %% [markdown]
# ### Q9

# %%
for(i in 1:length(core_nodes)){
    core_node = core_nodes[i]
    personalized_1 = personalized_networks[[i]]
    print(vcount(personalized_1))
    print(ecount(personalized_1))
    comms_fg= cluster_fast_greedy(personalized_1, modularity=TRUE)
    
    fg_node_color <- comms_fg$membership + 1
    
    comms_eb= cluster_edge_betweenness(personalized_1, modularity=TRUE)
    
    eb_node_color <- comms_eb$membership + 1
    
    comms_i= cluster_infomap(personalized_1, modularity=TRUE)
    
    i_node_color <- comms_eb$membership + 1
    
    printf("Modularity of fg %d = %.4f\n", core_node, modularity(comms_fg))
    printf("Modularity of eb %d = %.4f\n", core_node, modularity(comms_eb))
    printf("Modularity of i %d = %.4f\n", core_node, modularity(comms_i))

    png(sprintf("plots/p2q1_9_%d_fg.png", core_nodes[i]))
    plot(personalized_1, mark.groups=groups(comms_fg), vertex.size=5, vertex.label=NA,vertex.color=fg_node_color,main=paste("Community Structure (Fast-Greedy, core node ",core_nodes[i],")",collapse=""))
    dev.off()
    png(sprintf("plots/p2q1_9_%d_eb.png", core_nodes[i]))
    plot(personalized_1, mark.groups=groups(comms_eb), vertex.size=5, vertex.label=NA,vertex.color=eb_node_color,main=paste("Community Structure (Edge-betweenness, core node ",core_nodes[i],")",collapse=""))
    dev.off()
    png(sprintf("plots/p2q1_9_%d_i.png", core_nodes[i]))
    plot(personalized_1, mark.groups=groups(comms_i), vertex.size=5, vertex.label=NA, vertex.color=i_node_color,main=paste("Community Structure (Infomap, core node ",core_nodes[i],")",collapse=""))
    dev.off()
    

    plot(personalized_1, mark.groups=groups(comms_fg), vertex.size=5, vertex.label=NA, vertex.color=fg_node_color,main=paste("Community Structure (Fast-Greedy, core node ",core_nodes[i],")",collapse=""))
    plot(personalized_1, mark.groups=groups(comms_eb), vertex.size=5, vertex.label=NA, vertex.color=eb_node_color,main=paste("Community Structure (Edge-betweennness, core node ",core_nodes[i],")",collapse=""))
    plot(personalized_1, mark.groups=groups(comms_i), vertex.size=5, vertex.label=NA, vertex.color=i_node_color,main=paste("Community Structure (Infomap, core node ",core_nodes[i],")",collapse=""))
}
# Out:
# [1] 348
# [1] 2866
# Modularity of fg 1 = 0.4131
# Modularity of eb 1 = 0.3533
# Modularity of i 1 = 0.3891
# Plot with title "Community Structure (Fast-Greedy, core node  1 )"
# [1] 1046
# [1] 27795
# Modularity of fg 108 = 0.4359
# Modularity of eb 108 = 0.5068
# Modularity of i 108 = 0.5082
# Plot with title "Community Structure (Edge-betweennness, core node  1 )"
# Plot with title "Community Structure (Infomap, core node  1 )"
# Plot with title "Community Structure (Fast-Greedy, core node  108 )"
# [1] 230
# [1] 3441
# Modularity of fg 349 = 0.2517
# Modularity of eb 349 = 0.1335
# Modularity of i 349 = 0.0955
# Plot with title "Community Structure (Edge-betweennness, core node  108 )"
# Plot with title "Community Structure (Infomap, core node  108 )"
# Plot with title "Community Structure (Fast-Greedy, core node  349 )"
# [1] 232
# [1] 4525
# Modularity of fg 484 = 0.5070
# Modularity of eb 484 = 0.4891
# Modularity of i 484 = 0.5153
# Plot with title "Community Structure (Edge-betweennness, core node  349 )"
# Plot with title "Community Structure (Infomap, core node  349 )"
# Plot with title "Community Structure (Fast-Greedy, core node  484 )"
# [1] 206
# [1] 7409
# Modularity of fg 1087 = 0.1455
# Modularity of eb 1087 = 0.0276
# Modularity of i 1087 = 0.0269
# Plot with title "Community Structure (Edge-betweennness, core node  484 )"
# Plot with title "Community Structure (Infomap, core node  484 )"
# Plot with title "Community Structure (Fast-Greedy, core node  1087 )"
# Plot with title "Community Structure (Edge-betweennness, core node  1087 )"
# Plot with title "Community Structure (Infomap, core node  1087 )"

# %% [markdown]
# ### Q10

# %%
core_removed_personalized_networks = array(NA, 5)

for(i in 1:length(core_nodes)){
    core_node = core_nodes[i]
    for(v in V(personalized_networks[[i]])){
        if(vertex_attr(personalized_networks[[i]], index=v, name="id") == core_node){
            core_removed_personalized_network = delete_vertices(personalized_networks[[i]], v)
            #print(vcount(personalized_networks[[i]]))
            #print(vcount(core_removed_personalized_network))
            comms_fg= cluster_fast_greedy(core_removed_personalized_network, modularity=TRUE)
            comms_eb= cluster_edge_betweenness(core_removed_personalized_network, modularity=TRUE)
            comms_i= cluster_infomap(core_removed_personalized_network, modularity=TRUE)
            fg_node_color <- comms_fg$membership + 1
            eb_node_color <- comms_eb$membership + 1
            i_node_color <- comms_i$membership + 1
            printf("Modularity of fg %d = %.4f\n", core_node, modularity(comms_fg))
            printf("Modularity of eb %d = %.4f\n", core_node, modularity(comms_eb))
            printf("Modularity of i %d = %.4f\n", core_node, modularity(comms_i))
            
            png(sprintf("plots/p2q1_10_%d_fg.png", core_node))
            plot(core_removed_personalized_network, mark.groups=groups(comms_fg), vertex.size=5, vertex.label=NA, vertex.color=fg_node_color)
            dev.off()
            png(sprintf("plots/p2q1_10_%d_eb.png", core_node))
            plot(core_removed_personalized_network, mark.groups=groups(comms_eb), vertex.size=5, vertex.label=NA, vertex.color=eb_node_color)
            dev.off()
            png(sprintf("plots/p2q1_10_%d_i.png", core_node))
            plot(core_removed_personalized_network, mark.groups=groups(comms_i), vertex.size=5, vertex.label=NA, vertex.color=i_node_color)
            dev.off()
            
            plot(core_removed_personalized_network, mark.groups=groups(comms_fg), vertex.size=5, vertex.label=NA,vertex.color=fg_node_color)
            plot(core_removed_personalized_network, mark.groups=groups(comms_eb), vertex.size=5, vertex.label=NA,vertex.color=eb_node_color)
            plot(core_removed_personalized_network, mark.groups=groups(comms_i), vertex.size=5, vertex.label=NA,vertex.color=i_node_color)
        }
    }
}
# Out:
# Modularity of fg 1 = 0.4419
# Modularity of eb 1 = 0.4161
# Modularity of i 1 = 0.4180
# Plot with title ""
# Modularity of fg 108 = 0.4581
# Modularity of eb 108 = 0.5213
# Modularity of i 108 = 0.5186
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Modularity of fg 349 = 0.2457
# Modularity of eb 349 = 0.1506
# Modularity of i 349 = 0.2466
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Modularity of fg 484 = 0.5342
# Modularity of eb 484 = 0.5154
# Modularity of i 484 = 0.5434
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Modularity of fg 1087 = 0.1482
# Modularity of eb 1087 = 0.0325
# Modularity of i 1087 = 0.0274
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %% [markdown]
# ### Q11

# %% [markdown]
# Embeddedness (v) = degree(v) - 1

# %% [markdown]
# ### Q12

# %%
core_node_new_ids = array(NA, 5)

# %%
for(i in 1:length(core_nodes)){
    core_node = core_nodes[i]
    for(v in V(personalized_networks[[i]])){
        if(vertex_attr(personalized_networks[[i]], index=v, name="id") == core_node){
            core_node_new_ids[i] = v;
            break;
        }
    }
}
#finding index of core node inside their personalized network

# %%
print(core_node_new_ids)
# Out:
# [1]  1  3  5 41 38

# %%
for(i in 1:length(core_nodes)){
    core_node = core_nodes[i]
    
    other_nodes = setdiff(V(personalized_networks[[i]]), core_node_new_ids[i])
    
    png(sprintf("plots/p2q1_12_%d_embed.png", core_node))
    hist(degree(personalized_networks[[i]], v=other_nodes)-1, main=paste("Distribution of embeddedness for node ID ",core_nodes[i]),xlab="Embeddedness value",ylab="No of nodes")
    dev.off()
    
    
}

# %%
for(i in 1:length(core_nodes)){
    core_node = core_nodes[i]
    personalized = personalized_networks[[i]]
    
    core_neighbors = neighbors(personalized, v=core_node_new_ids[i])
    dispersions = array(NA, length(core_neighbors))
    
    for(j in 1:length(core_neighbors)){
        neighbor = core_neighbors[j]
        neighbors_neighbors = neighbors(personalized, v=neighbor)
        mutual_neighbors = intersection(core_neighbors, neighbors_neighbors)
        
        removed_network = delete_vertices(personalized, c(core_node_new_ids[i], neighbor))
        
        mut = V(removed_network)[V(removed_network)$id %in% mutual_neighbors$id]
        
        dist = distances(removed_network, v=mut, to=mut)
        dist[is.infinite(dist)] = 0
        
        dis = sum(dist) / 2
        dispersions[j] = dis
        #print(dis)
    }
    png(sprintf("plots/p2q1_12_%d_dist.png", core_node))
    hist(dispersions, main=paste("Distribution of Dispersion for node ID ",core_nodes[i]),xlab="Dispersion value",ylab="No of nodes")
    dev.off()
    
}

# %% [markdown]
# ### Q13 & 14

# %%
start_time <- Sys.time()

for(i in 1:length(core_nodes)){
    core_node = core_nodes[i]
    personalized = personalized_networks[[i]]
    
    core_neighbors = neighbors(personalized, v=core_node_new_ids[i])   
    embeddedness = degree(personalized, v=core_neighbors)-1;
    
    dispersions = array(NA, length(core_neighbors))
    
    for(j in 1:length(core_neighbors)){
        neighbor = core_neighbors[j]
        neighbors_neighbors = neighbors(personalized, v=neighbor)
        mutual_neighbors = intersection(core_neighbors, neighbors_neighbors)
        
        
        removed_network = delete_vertices(personalized, c(core_node_new_ids[i], neighbor))
        
        mut = V(removed_network)[V(removed_network)$id %in% mutual_neighbors$id]
        
        dist = distances(removed_network, v=mut, to=mut)
        dist[is.infinite(dist)] = 0
        
        dis = sum(dist) / 2
        dispersions[j] = dis
    }
    
    
    max_dis_node = core_neighbors[which.max(dispersions)]$id
    
    max_em_node = core_neighbors[which.max(embeddedness)]$id
    
    printf("Node with maximum dispersion for core node %d is %d\n", core_node, max_dis_node)
    printf("Max dispersion value is %f\n", max(dispersions));
    
    printf("Node with maximum embeddedness for core node %d is %d\n", core_node, max_em_node)
    printf("Max embeddedness value is %f\n", max(embeddedness));
    
    argmax_dis_over_em = -1;
    max_dis_over_em = -1;
    
    for(j in 1:length(core_neighbors)){
        if(embeddedness[j] > 0){
            if(dispersions[j]/embeddedness[j] > max_dis_over_em){
                max_dis_over_em = dispersions[j]/embeddedness[j]
                argmax_dis_over_em = j
            }
        }
    }
    
    max_dis_em_node =  core_neighbors[argmax_dis_over_em]$id
    
    printf("Node with maximum dispersion/embeddedness for core node %d is %d\n", core_node, max_dis_em_node)
    printf("Max dispersion/embeddedness value is %f\n", max_dis_over_em);
    
    comms_fg= cluster_fast_greedy(personalized, modularity=TRUE)
    
    edge_color = rep("gray", length(E(personalized)))
    edge_weight = rep(0.5, length(E(personalized)))
    node_color = comms_fg$membership
    node_size = rep(5, length(V(personalized)))

    edge_color[incident(personalized, which(V(personalized)$id == max_dis_node))] = "red";
    edge_weight[incident(personalized, which(V(personalized)$id == max_dis_node))] = 2;
    
    node_color[which(V(personalized)$id == core_node_new_ids[i])] = "hotpink";
    node_color[which(V(personalized)$id == max_dis_node)] = "red";
    
    node_size[which(V(personalized)$id == max_dis_node)] = 7;
    node_size[which(V(personalized)$id == core_node_new_ids[i])] = 7;
        
    png(sprintf("plots/p2q1_13_dis_%d.png", core_node))
            
    
    plot(personalized, vertex.size=node_size, vertex.label=NA, vertex.color = node_color, edge.width = edge_weight, edge.color = edge_color)
    dev.off()
    
    #embededdness
    
    edge_color = rep("gray", length(E(personalized)))
    edge_weight = rep(0.5, length(E(personalized)))
    node_color = comms_fg$membership
    node_size = rep(5, length(V(personalized)))
    
    edge_color[incident(personalized, which(V(personalized)$id == max_em_node))] = "red";
    edge_weight[incident(personalized, which(V(personalized)$id == max_em_node))] = 2;
    
    node_color[which(V(personalized)$id == core_node_new_ids[i])] = "hotpink";
    node_color[which(V(personalized)$id == max_em_node)] = "red";
    
    node_size[which(V(personalized)$id == max_em_node)] = 7;
    node_size[which(V(personalized)$id == core_node_new_ids[i])] = 7;
    
    png(sprintf("plots/p2q1_14_em_%d.png", core_node))
    plot(personalized, vertex.size=node_size, vertex.label=NA, vertex.color = node_color, edge.width = edge_weight, edge.color = edge_color)
    dev.off()
    
    #dispersion/embeddedness
    
    edge_color = rep("gray", length(E(personalized)))
    edge_weight = rep(0.5, length(E(personalized)))
    node_color = comms_fg$membership
    node_size = rep(5, length(V(personalized)))
    
    edge_color[incident(personalized, which(V(personalized)$id == max_dis_em_node))] = "red";
    edge_weight[incident(personalized, which(V(personalized)$id == max_dis_em_node))] = 2;
    
    max_dis_node_edge=length(incident(personalized, which(V(personalized)$id == max_dis_node)))
    max_em_node_edge=length(incident(personalized, which(V(personalized)$id == max_em_node)))
    max_dis_em_node_edge=length(incident(personalized, which(V(personalized)$id == max_dis_em_node)))
    
    printf("No of incident edges to the node with maximum dispersion for core node %d is %d\n", core_node, max_dis_node_edge)
    printf("No of incident edges to the node with maximum embeddedness for core node %d is %d\n", core_node, max_em_node_edge)
    printf("No of incident edges to the node with maximum dispersion/embeddedness for core node %d is %d\n", core_node, max_dis_em_node_edge)
        
    node_color[which(V(personalized)$id == core_node_new_ids[i])] = "hotpink";
    node_color[which(V(personalized)$id == max_dis_em_node)] = "red";
    
    node_size[which(V(personalized)$id == max_dis_em_node)] = 7;
    node_size[which(V(personalized)$id == core_node_new_ids[i])] = 7;
    
    png(sprintf("plots/p2q1_14_dis_em_%d.png", core_node))
    plot(personalized, vertex.size=node_size, vertex.label=NA, vertex.color = node_color, edge.width = edge_weight, edge.color = edge_color)
    dev.off()    
}
# Out:
# Node with maximum dispersion for core node 1 is 57
# Max dispersion value is 4971.000000
# Node with maximum embeddedness for core node 1 is 57
# Max embeddedness value is 77.000000
# Node with maximum dispersion/embeddedness for core node 1 is 26
# Max dispersion/embeddedness value is 66.220588
# No of incident edges to the node with maximum dispersion for core node 1 is 78
# No of incident edges to the node with maximum embeddedness for core node 1 is 78
# No of incident edges to the node with maximum dispersion/embeddedness for core node 1 is 69
# Node with maximum dispersion for core node 108 is 1889
# Max dispersion value is 51247.000000
# Node with maximum embeddedness for core node 108 is 1889
# Max embeddedness value is 253.000000
# Node with maximum dispersion/embeddedness for core node 108 is 1889
# Max dispersion/embeddedness value is 202.557312
# No of incident edges to the node with maximum dispersion for core node 108 is 254
# No of incident edges to the node with maximum embeddedness for core node 108 is 254
# No of incident edges to the node with maximum dispersion/embeddedness for core node 108 is 254
# Node with maximum dispersion for core node 349 is 377
# Max dispersion value is 8258.000000
# Node with maximum embeddedness for core node 349 is 377
# Max embeddedness value is 100.000000
# Node with maximum dispersion/embeddedness for core node 349 is 377
# Max dispersion/embeddedness value is 82.580000
# No of incident edges to the node with maximum dispersion for core node 349 is 101
# No of incident edges to the node with maximum embeddedness for core node 349 is 101
# No of incident edges to the node with maximum dispersion/embeddedness for core node 349 is 101
# Node with maximum dispersion for core node 484 is 108
# Max dispersion value is 29837.000000
# Node with maximum embeddedness for core node 484 is 108
# Max embeddedness value is 166.000000
# Node with maximum dispersion/embeddedness for core node 484 is 108
# Max dispersion/embeddedness value is 179.740964
# No of incident edges to the node with maximum dispersion for core node 484 is 167
# No of incident edges to the node with maximum embeddedness for core node 484 is 167
# No of incident edges to the node with maximum dispersion/embeddedness for core node 484 is 167
# Node with maximum dispersion for core node 1087 is 108
# Max dispersion value is 40969.000000
# Node with maximum embeddedness for core node 1087 is 108
# Max embeddedness value is 204.000000
# Node with maximum dispersion/embeddedness for core node 1087 is 108
# Max dispersion/embeddedness value is 200.828431
# No of incident edges to the node with maximum dispersion for core node 1087 is 205
# No of incident edges to the node with maximum embeddedness for core node 1087 is 205
# No of incident edges to the node with maximum dispersion/embeddedness for core node 1087 is 205
